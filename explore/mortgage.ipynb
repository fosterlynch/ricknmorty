# %%
import matplotlib.pyplot as plt

from realestate import RealEstate, webvalues

# %%
## TEST VALUES
list_price = 194750

# grab from webpage
taxes = 14000/12
insurance= 100
hoa_fees = 0
rental_income = 600

# %%
list_price = 194750
# grab from webpage
taxes = 14000/12
insurance= 100
hoa_fees = 0
rental_income = 850*4

wv = webvalues(property_type="single", 
               list_price=list_price, 
               rental_income=rental_income, 
               insurance=insurance, 
               taxes=taxes, 
               hoa=hoa_fees)

house = RealEstate(webvalues=wv)

# %%
house.generate_full_report()
# Out:
# values for property as a multi property
# expenses: $3445.036666666667 / month
# cashflow: $-45.04 / month
# down_payment: $38950.0 down
# return on investment: -1.0 %
# time to recoup investment: (72.06557134399053, 'years')
# ------------
# values for property as a single property
# expenses: $2964.009666666667 / month
# cashflow: $435.99 / month
# down_payment: $5842.5 down
# return on investment: 90.0 %
# time to recoup investment: (1.1167113924631298, 'years')
# resetting back to initialized values
# monthly payment:  1014.1
# Original Balance:         $  188,907.5
# Interest Rate:                    0.05 %
# APY:                              5.12 %
# APR:                              5.00 %
# Term:                               30 years
# Monthly Payment:          $    1014.10
#
# Total principal payments: $ 188,907.50
# Total interest payments:  $ 176,167.17
# Total payments:           $ 365,074.67
# Interest to principal:            93.3 %
# ...

# %%
house.loan._schedule
# Out:
# [Installment(number=0, payment=0, interest=0, principal=0, total_interest=0, balance=Decimal('388000')),
#  Installment(number=1, payment=Decimal('2082.867897287099261134551135'), interest=Decimal('1616.666666666666666666666667'), principal=Decimal('466.201230620432594467884468'), total_interest=Decimal('1616.666666666666666666666667'), balance=Decimal('387533.7987693795674055321155')),
#  Installment(number=2, payment=Decimal('2082.867897287099261134551135'), interest=Decimal('1614.724161539081530856383815'), principal=Decimal('468.143735748017730278167320'), total_interest=Decimal('3231.390828205748197523050482'), balance=Decimal('387065.6550336315496752539482')),
#  Installment(number=3, payment=Decimal('2082.867897287099261134551135'), interest=Decimal('1612.773562640131456980224784'), principal=Decimal('470.094334646967804154326351'), total_interest=Decimal('4844.164390845879654503275266'), balance=Decimal('386595.5606989845818710996218')),
# ...

# %%
for s in house.loan._schedule:
    print(s.balance)
    break
# Out:
# 189150

# %%
house.plot_equity()
house.plot_debt()
plt.show()
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_amortize', '_currency', '_monthly_payment', '_quantize', '_schedule', '_simple_interest', 'apr', 'apy', 'compounded', 'interest', 'interest_to_principle', 'monthly_payment', 'n_periods', 'principal', 'schedule', 'split_payment', 'summarize', 'term', 'term_unit', 'total_interest', 'total_paid', 'total_principal', 'years_to_pay']

# %%
# Out:
# values for property as a multi property
# expenses: $2381.036666666667 / month
# cashflow: $-1781.04 / month
# down_payment: $38950.0 down
# return on investment: -55.00000000000001 %
# time to recoup investment: (1.8224370779619399, 'years')
# ------------
# values for property as a single property
# expenses: $2964.009666666667 / month
# cashflow: $-2364.01 / month
# down_payment: $5842.5 down
# return on investment: -486.00000000000006 %
# time to recoup investment: (2.471436246039568, 'months')
# resetting back to initialized values
# monthly payment:  1014.1
# Original Balance:         $  188,907.5
# Interest Rate:                    0.05 %
# APY:                              5.12 %
# APR:                              5.00 %
# Term:                               30 years
# Monthly Payment:          $    1014.10
#
# Total principal payments: $ 188,907.50
# Total interest payments:  $ 176,167.17
# Total payments:           $ 365,074.67
# Interest to principal:            93.3 %
# ...

# %%
house.analyze()
print(house.monthly_payment)
print(house.loan.summarize)
house._expenses
# Out:
# values for property as a multi property
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [208], in <cell line: 1>()
# ----> 1 house.analyze()
#       2 print(house.monthly_payment)
#       3 print(house.loan.summarize)
#
# Input In [206], in RealEstate.analyze(self)
#     151 self.property_type = "multi"
#     152 self.set_expenses()
# --> 153 self.print_numbers()
#     155 print("------------")
#     156 self.property_type = "single"
#
# Input In [206], in RealEstate.print_numbers(self)
#     141 def print_numbers(self):
#     142     print(f"values for property as a {self.property_type} property")
# --> 143     print(f"expenses: ${self.monthly_expenses()} / month")
#     144     print(f"cashflow: ${self.cashflow()} / month")
#     145     print(f"down_payment: ${self.down_payment} down")
#
# Input In [206], in RealEstate.monthly_expenses(self)
# ...

# %%
[self.capex, 
                self.mgmt_fees, 
                self.misc_expenses, 
                self.repairs, 
                self.vacancy, 
                self.water_sewer,
                self.garbage,
                self.lawn,
                self.electric,
                self.gas,
                self.hoa,
                self.taxes,
                self.insurance,
                self.monthly_payment
               ]

# %%
# utils = utilValues(gas = 100)
# print(utils.gas)
# if i pass in utils, then i can modify the RealEstate class without changing the internal code
# but if i dont, then my class will be populated with some defauly values

# next steps
# analyze as ...
# exclusive airbnb (utilities paid by me)
# pure single family live in
# if its Multifamily, what are the numbers for 


wv = webvalues(property_type="single", list_price=list_price, rental_income=rental_income, insurance=insurance, taxes=taxes, hoa=hoa_fees)

house = RealEstate(webvalues=wv)
house.vizualize_property_value()
